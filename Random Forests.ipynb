# %% [markdown]
# # Random Forests
# ensemble method, collection of decision trees
# randomly selects data from data set (with replacement) and build a Decision tree with each new sample
# ## Data set originates from publicly available data from Lendingclub.com from between 2007-2010
# The website allowed investors and borrowers to connect.
# The idea here is that we create a model to decide whether or not a customer will payback or default on the loan given.
#
# Here are what the columns represent:
# * credit.policy: 1 if the customer meets the credit underwriting criteria of LendingClub.com, and 0 otherwise.
# * purpose: The purpose of the loan (takes values "credit_card", "debt_consolidation", "educational", "major_purchase", "small_business", and "all_other").
# * int.rate: The interest rate of the loan, as a proportion (a rate of 11% would be stored as 0.11). Borrowers judged by LendingClub.com to be more risky are assigned higher interest rates.
# * installment: The monthly installments owed by the borrower if the loan is funded.
# * log.annual.inc: The natural log of the self-reported annual income of the borrower.
# * dti: The debt-to-income ratio of the borrower (amount of debt divided by annual income).
# * fico: The FICO credit score of the borrower.
# * days.with.cr.line: The number of days the borrower has had a credit line.
# * revol.bal: The borrower's revolving balance (amount unpaid at the end of the credit card billing cycle).
# * revol.util: The borrower's revolving line utilization rate (the amount of the credit line used relative to total credit available).
# * inq.last.6mths: The borrower's number of inquiries by creditors in the last 6 months.
# * delinq.2yrs: The number of times the borrower had been 30+ days past due on a payment in the past 2 years.
# * pub.rec: The borrower's number of derogatory public records (bankruptcy filings, tax liens, or judgments).

# %%
#setup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set_style('darkgrid')

# %%
# data overview
loans = pd.read_csv('data/loan_data.csv')
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Data set of 9577 entries without Null values to deal with

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
sns.countplot(x='not.fully.paid', data=loans)
# Out:
# <AxesSubplot:xlabel='not.fully.paid', ylabel='count'>

# %% [markdown]
# ## Our label variable is skewed to the positive could introduce bias into the model

# %% [markdown]
# # Exploratory Data Analysis

# %%
yes_fico = loans[loans['credit.policy'] == 1]['fico']
no_fico = loans[loans['credit.policy'] == 0]['fico']
plt.figure(figsize=(10,6))
sns.distplot(yes_fico, color='blue', bins=30,label='Credit.policy=1',kde=False)
sns.distplot(no_fico, color='red', bins=30, label='Credit.policy=0',kde=False)
plt.xlabel('FICO')
plt.legend()
# Out:
# /home/oliver/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
not_fully = loans[loans['not.fully.paid'] == 1]['fico']
fully = loans[loans['not.fully.paid'] == 0]['fico']
plt.figure(figsize=(10,6))
sns.distplot(not_fully, bins=30, kde=False, label='not.fully.paid=1', color='blue')
sns.distplot(fully, bins=30, kde=False, label='not.fully.paid=0', color='red')
plt.xlabel('FICO')
plt.legend()

# %% [markdown]
# ## FICO score seems to have a large affect on if the customer meets the credit underwriting criteria of LendingClub.com, but less predictive over whether the loan will actually be payed off

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='purpose', data=loans, hue='not.fully.paid',)
plt.xlabel('Purpose')
plt.tight_layout()

# %% [markdown]
# ## Observing the relationship between purpose and whether the loan has been payed off

# %%
sns.jointplot(x='fico', y='int.rate', data=loans, kind='hex', color='purple')

# %% [markdown]
# ## Clearly the intrest rate of loans provided is typically heigher the lower the FICO score, which is as expected as lenders will percieve a greater risk

# %%
sns.lmplot(x='fico', y='int.rate', data=loans, col='not.fully.paid', hue='credit.policy')

# %% [markdown]
# ## This visualisation clearly shows that appart from a few anomylies that credit policy being given is having a FICO score above 660

# %% [markdown]
# # Setting up data and feature engineering

# %% [markdown]
# ### purpose columns is categorical -> get dummies for the model

# %%
final_data = pd.get_dummies(loans,columns=['purpose'],drop_first=True)

# %%
final_data.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation  \
# ...

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_data.drop('not.fully.paid', axis=1)
y = final_data['not.fully.paid']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Training a Decision Tree Model - single decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predictions and Evaluation of Decision Tree

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
predictions = dtree.predict(X_test)

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test, predictions))
# Out:
# [[2009  399]
#  [ 370   96]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84      2408
#            1       0.19      0.21      0.20       466
#
#     accuracy                           0.73      2874
#    macro avg       0.52      0.52      0.52      2874
# weighted avg       0.74      0.73      0.74      2874

# %% [markdown]
# ## very poor performance determining the people not paying back the loan
# ### can be explained via the skew in the data set to the 0 value for not.fully.payed

# %% [markdown]
# # Let's see if- Training the Random Forest model improves performance

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
predictions = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test, predictions))
# Out:
# [[2394   14]
#  [ 455   11]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91      2408
#            1       0.44      0.02      0.04       466
#
#     accuracy                           0.84      2874
#    macro avg       0.64      0.51      0.48      2874
# weighted avg       0.78      0.84      0.77      2874

# %% [markdown]
# ## performance got better with percision (avoiding false positives) but worse at (avoiding false negatives)
# ### for the case of the lenders the previous model would be prefered for concervatism, but performance of both models is rather poor
